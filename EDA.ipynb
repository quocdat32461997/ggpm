# %% [markdown]
# # Preprocess for datasets

# %%
import os
import numpy as np
import pandas as pd
from rdkit import Chem
import matplotlib.pyplot as plt
from collections import Counter, OrderedDict

# %%
def compute_stats(data):
    # Gather info
    mol_stats_info = {'num_atom': [], 'num_bond': [], 'num_ring': [], 'ring_size': []}
    atom_vocab = []
    
    for smiles in data['SMILES']:
        mol = Chem.MolFromSmiles(smiles)

        rings = Chem.GetSymmSSSR(mol)

        mol_stats_info['num_atom'].append(mol.GetNumAtoms())
        mol_stats_info['num_bond'].append(mol.GetNumBonds())
        mol_stats_info['num_ring'].append(len(rings))
        mol_stats_info['ring_size'].extend([len(ring) for ring in rings]) #+= sum([len(ring) for ring in rings]) / len(rings)

        for atom in mol.GetAtoms():
            atom_vocab.append(atom.GetSymbol())

    # Compute stats for molecular graph
    mol_stats = {key: [np.mean(val), np.std(val)] for key, val in mol_stats_info.items()}
    mol_stats['atom_vocab_size'] = len(set(atom_vocab))
    print('Stats of molecular graph', mol_stats)

    # Compute stats for properties
    print('Stats of HOMO', np.mean(data['HOMO']), np.std(data['HOMO']))
    print('Stats of LUMO', np.mean(data['LUMO']), np.std(data['LUMO']))

# %% [markdown]
# ## Curated-OPV

# %% [markdown]
# ### Clean data

# %%
data = pd.read_csv('/Users/datqngo/Desktop/projects/ggpm/data/chem_data/cleaned_data.csv')

# %% [markdown]
# ### Analysis

# %%
compute_stats(data)
# Out:
# Stats of molecular graph {'num_atom': [98.73333333333333, 46.627555038720274], 'num_bond': [110.9, 52.258874844374525], 'num_ring': [13.166666666666666, 5.9137316664033905], 'ring_size': [5.50253164556962, 0.4999935907296312], 'atom_vocab_size': 8}
# Stats of HOMO -5.50340425531915 0.3903259772197215
# Stats of LUMO -3.8730612244897964 0.4658904315509661

# %% [markdown]
# ## HOPV15

# %%
data = pd.read_csv('data/hopv15/hopv15.csv')

# %%
compute_stats(data)
# Out:
# Stats of molecular graph {'num_atom': [42.78285714285714, 13.812157909698577], 'num_bond': [49.30285714285714, 16.09542056814006], 'num_ring': [7.525714285714286, 2.596298778441876], 'ring_size': [5.37661351556568, 0.48453666059333345], 'atom_vocab_size': 7}
# Stats of HOMO -0.18954285714285712 0.010778928802179231
# Stats of LUMO -0.09989428571428571 0.01604966297567189

# %% [markdown]
# ## QM9

# %%
data = pd.read_csv('data/qm9/qm9.csv')

# %%
compute_stats(data)

# %% [markdown]
# ## Motif Vocab

# %%
with open('trio_polymer_vocab.txt', 'r') as file:
    motif_list = file.readlines()

# %%
import re
from collections import defaultdict

motif_dict = defaultdict(int)
motif_size_dict = defaultdict(int)
attm_pos_list = []

for motif in motif_list:
    motif, attm, _ = motif.split()
    #print(motif, attm)
    if motif not in motif_size_dict:
        motif_size = Chem.MolFromSmiles(motif).GetNumAtoms()
        motif_size_dict[motif] = motif_size

    num_attm_pos = len(re.findall(r':[0-9]+', attm))
    motif_dict[motif] += 1
    
#    if len(motif_dict) > 30: 
#        break

    attm_pos_list.append(max(1, num_attm_pos))

#print(motif_dict)
# states for attachment
print(len(motif_list))
print(np.mean(list(motif_dict.values())), np.std(list(motif_dict.values())))
print(np.mean(attm_pos_list), np.std(attm_pos_list))

# stats for motifs

print(np.mean(list(motif_size_dict.values())), np.std(list(motif_size_dict.values())))
# Out:
# 6215
# 8.619972260748959 13.488160545278527
# 2.3549477071600964 1.345352559343009
# 6.160887656033287 1.7865800521672286

# %%
any(([0 > x for x in list(motif_dict.values())]))
# Out:
# False

# %%
x = Counter(list(motif_dict.values()))
#x = sorted(x.items(), key = lambda x: x[0])
#x = {k: v for k, v in x}

# %%
motif_dict
# Out:
# defaultdict(int,
#             {'C': 1,
#              'C#C': 2,
#              'C#CC': 3,
#              'C#CC#CC': 3,
#              'C#CC(C)=O': 3,
#              'C#CC(C)C': 4,
#              'C#CC(C)O': 3,
#              'C#CCC': 3,
#              'C#CCCC': 3,
#              'C#CCN': 3,
#              'C#N': 3,
#              'C1#CC=CCC=CC=C1': 1,
#              'C1#CC=CCCCC=C1': 1,
#              'C1#CC=CCOCC=C1': 1,
#              'C1#CCC=CC=CC=C1': 1,
#              'C1#CCC=CCC=CC1': 1,
#              'C1#CCC=CCCC=C1': 1,
#              'C1#CCCC=CC=CC1': 1,
#              'C1#CCCC=CCC=C1': 1,
#              'C1#CCCCC=CC=C1': 1,
#              'C1#CCCCC=CCC1': 1,
#              'C1#CCCCCC=CC1': 1,
#              'C1#CCCCCCC=C1': 1,
#              'C1#CCCCCCCC1': 1,
#              'C1#CCCCOCC=C1': 1,
#              'C1#CCCCOCCC1': 1,
#              'C1#CCCOC=NCC1': 1,
#              'C1#CCCOCC=CC1': 1,
#              'C1#CCCOCCC=C1': 1,
#              'C1#CCCOCCCC1': 1,
#              'C1#CCCOCOCC1': 1,
#              'C1#CCN=CNC=NC1': 1,
#              'C1#CCN=COCC=C1': 1,
#              'C1#CCN=COCCC1': 1,
#              'C1#CCOC=NCC=C1': 1,
#              'C1#CCOC=NCCC1': 1,
#              'C1#CCOCC=CC=C1': 1,
#              'C1#CCOCC=CCC1': 1,
#              'C1#CCOCCC=CC1': 1,
#              'C1#CCOCCCC=C1': 1,
#              'C1#CCOCCCCC1': 1,
#              'C1#CCOCCCOC1': 1,
#              'C1#CCOCCOCC1': 1,
#              'C1#CCOCOC=NC1': 1,
#              'C1#CCOCOCC=C1': 1,
#              'C1#CCOCOCCC1': 1,
#              'C1=CC2CC2C1': 7,
#              'C1=CC2NC2C1': 6,
#              'C1=CC2OC2C1': 5,
#              'C1=CC=CC=C1': 34,
#              'C1=CC=CC=CC=C1': 1,
#              'C1=CC=CCC=C1': 20,
#              'C1=CC=CCC=CC=C1': 1,
#              'C1=CC=CCCC=C1': 5,
#              'C1=CC=CCCCC=C1': 1,
#              'C1=CC=CCOCC=C1': 1,
#              'C1=CC=CNC=C1': 1,
#              'C1=CC=CNCC=C1': 1,
#              'C1=CC=COC=CC=C1': 1,
#              'C1=CC=COC=NC=C1': 1,
#              'C1=CC=C[NH]C=CC=C1': 1,
#              'C1=CC=C[NH]C=NC=C1': 1,
#              'C1=CC=NC=C1': 42,
#              'C1=CC=NC=COC=C1': 1,
#              'C1=CC=NC=C[NH]C=C1': 1,
#              'C1=CC=NCC=C1': 11,
#              'C1=CC=NCN=C1': 5,
#              'C1=CC=NN=C1': 6,
#              'C1=CC=S=C1': 8,
#              'C1=CCC=C1': 13,
#              'C1=CCC=CC1': 7,
#              'C1=CCC=CCC=C1': 4,
#              'C1=CCC=CCC=CC1': 1,
#              'C1=CCC=CCCC=C1': 1,
#              'C1=CCC=CN=C1': 11,
#              'C1=CCC=NC=C1': 11,
#              'C1=CCCC1': 61,
#              'C1=CCCC=C1': 24,
#              'C1=CCCC=CC1': 31,
#              'C1=CCCC=CCC1': 4,
#              'C1=CCCCC1': 89,
#              'C1=CCCCC=C1': 38,
#              'C1=CCCCC=CC1': 8,
#              'C1=CCCCC=CCC1': 1,
#              'C1=CCCCCC1': 59,
#              'C1=CCCCCC=C1': 9,
#              'C1=CCCCCC=CC1': 1,
#              'C1=CCCCCCC1': 12,
#              'C1=CCCCCCC=C1': 1,
#              'C1=CCCCCCCC1': 1,
#              'C1=CCCCNC=C1': 1,
#              'C1=CCCCOCC=C1': 1,
#              'C1=CCCCOCCC1': 1,
#              'C1=CCCN=C1': 3,
#              'C1=CCCN=CC1': 4,
#              'C1=CCCNC=C1': 14,
#              'C1=CCCNC=CC1': 2,
#              'C1=CCCNCC1': 22,
#              'C1=CCCNCC=C1': 3,
#              'C1=CCCNCCC1': 2,
#              'C1=CCCNN=C1': 4,
#              'C1=CCCOC=C1': 4,
#              'C1=CCCOC=NCC1': 1,
#              'C1=CCCOCC1': 34,
#              'C1=CCCOCC=C1': 9,
#              'C1=CCCOCC=CC1': 1,
#              'C1=CCCOCCC1': 13,
#              'C1=CCCOCCC=C1': 1,
#              'C1=CCCOCCCC1': 1,
#              'C1=CCCOCOCC1': 1,
#              'C1=CCCON=C1': 4,
#              'C1=CCC[CH-]1': 2,
#              'C1=CCN=C1': 7,
#              'C1=CCN=CCC1': 6,
#              'C1=CCN=CN=C1': 9,
#              'C1=CCN=COCC1': 7,
#              'C1=CCN=COCC=C1': 1,
#              'C1=CCN=COCCC1': 1,
#              'C1=CCNC1': 55,
#              'C1=CCNC=C1': 35,
#              'C1=CCNC=CC1': 20,
#              'C1=CCNC=CCC1': 2,
#              'C1=CCNC=NC1': 12,
#              'C1=CCNCC1': 117,
#              'C1=CCNCC=C1': 13,
#              'C1=CCNCC=CC1': 1,
#              'C1=CCNCCC1': 43,
#              'C1=CCNCCCC1': 3,
#              'C1=CCNCN=C1': 4,
#              'C1=CCNCNC1': 9,
#              'C1=CCNCNC=C1': 1,
#              'C1=CCNCNCC1': 1,
#              'C1=CCNCOCC1': 1,
#              'C1=CCNC[CH-]1': 2,
#              'C1=CCNN=C1': 23,
#              'C1=CCNN=CC1': 4,
#              'C1=CCNN=NC1': 4,
#              'C1=CCN[CH-]1': 4,
#              'C1=CCOC1': 31,
#              'C1=CCOC=C1': 29,
#              'C1=CCOC=CC1': 2,
#              'C1=CCOC=NC1': 22,
#              'C1=CCOC=NCC1': 7,
#              'C1=CCOC=NCCC1': 1,
#              'C1=CCOCC1': 84,
#              'C1=CCOCC=C1': 22,
#              'C1=CCOCC=CC1': 5,
#              'C1=CCOCC=CCC1': 1,
#              'C1=CCOCCC1': 64,
#              'C1=CCOCCCC1': 15,
#              'C1=CCOCCCCC1': 1,
#              'C1=CCOCCCOC1': 1,
#              'C1=CCOCCNC1': 7,
#              'C1=CCOCCOC1': 5,
#              'C1=CCOCCOCC1': 1,
#              'C1=CCOCN=C1': 4,
#              'C1=CCOCNC1': 13,
#              'C1=CCOCNC=C1': 1,
#              'C1=CCOCNCC1': 1,
#              'C1=CCOCOC1': 17,
#              'C1=CCOCOC=NC1': 1,
#              'C1=CCOCOCC1': 7,
#              'C1=CCOCOCC=C1': 1,
#              'C1=CCOCOCCC1': 1,
#              'C1=CCOC[CH-]1': 2,
#              'C1=CCON=C1': 18,
#              'C1=CCON=CC1': 4,
#              'C1=CCON=NC1': 4,
#              'C1=CCO[CH-]1': 7,
#              'C1=CCO[CH-]C1': 8,
#              'C1=CC[N-][NH+]=C1': 2,
#              'C1=CC[NH2+]C1': 15,
#              'C1=CC[NH2+]CC1': 5,
#              'C1=CC[NH2+][CH-]C1': 2,
#              'C1=CN=CC1': 6,
#              'C1=CN=CC=COC=C1': 1,
#              'C1=CN=CC=C[NH]C=C1': 1,
#              'C1=CN=CC=N1': 13,
#              'C1=CN=CC=NC1': 9,
#              'C1=CN=CCC1': 8,
#              'C1=CN=CCC=N1': 5,
#              'C1=CN=CCN=C1': 9,
#              'C1=CN=CCNC1': 4,
#              'C1=CN=CCOC1': 4,
#              'C1=CN=CN=C1': 25,
#              'C1=CN=CN=CC1': 9,
#              'C1=CN=CN=COC=C1': 1,
#              'C1=CN=CN=C[NH]C=C1': 1,
#              'C1=CN=CNC1': 25,
#              'C1=CN=CNCC1': 4,
#              'C1=CN=COC1': 19,
#              'C1=CN=COC=CN=C1': 1,
#              'C1=CN=COC=NC=C1': 1,
#              'C1=CN=COC=NC=N1': 1,
#              'C1=CN=COCC1': 4,
#              'C1=CN=C[NH]C=CN=C1': 1,
#              'C1=CN=C[NH]C=NC=C1': 1,
#              'C1=CN=C[NH]C=NC=N1': 1,
#              'C1=CN=NC=C1': 8,
#              'C1=CN=NC=CC1': 1,
#              'C1=CN=NC=N1': 6,
#              'C1=CN=NN=C1': 1,
#              'C1=CN=NN=N1': 1,
#              'C1=CN=NNC1': 15,
#              'C1=CN=NNCC1': 4,
#              'C1=CN=NOC1': 11,
#              'C1=CN=NOCC1': 4,
#              'C1=CN=[NH+][N-]C1': 2,
#              'C1=CNC=CC1': 18,
#              'C1=CNC=CCC1': 3,
#              'C1=CNC=NC1': 25,
#              'C1=CNC=NCC1': 6,
#              'C1=CNC=[NH+]C1': 3,
#              'C1=CNCC1': 84,
#              'C1=CNCC=CNC1': 1,
#              'C1=CNCC=N1': 24,
#              'C1=CNCC=NC1': 6,
#              'C1=CNCCC1': 81,
#              'C1=CNCCC=N1': 4,
#              'C1=CNCCCC1': 27,
#              'C1=CNCCCCC1': 2,
#              'C1=CNCCCNC1': 1,
#              'C1=CNCCCOC1': 2,
#              'C1=CNCCN1': 9,
#              'C1=CNCCN=C1': 4,
#              'C1=CNCCNC1': 22,
#              'C1=CNCCNCC1': 1,
#              'C1=CNCCOC1': 21,
#              'C1=CNCCOCC1': 2,
#              'C1=CNCN1': 20,
#              'C1=CNCN=C1': 24,
#              'C1=CNCN=CC1': 4,
#              'C1=CNCNC1': 38,
#              'C1=CNCNC=C1': 7,
#              'C1=CNCNC=CC1': 1,
#              'C1=CNCNC=NC1': 1,
#              'C1=CNCNCC1': 17,
#              'C1=CNCNCCC1': 1,
#              'C1=CNCNCN1': 2,
#              'C1=CNCOC1': 25,
#              'C1=CNCOC=NC1': 1,
#              'C1=CNCOCC1': 13,
#              'C1=CNCOCCC1': 1,
#              'C1=CNCOCOC1': 1,
#              'C1=CNC[CH-]C1': 10,
#              'C1=CNC[N-]1': 4,
#              'C1=CNN=CC1': 23,
#              'C1=CNN=CCC1': 4,
#              'C1=CNN=NC1': 15,
#              'C1=CNN=NCC1': 4,
#              'C1=CN[CH-]C1': 8,
#              'C1=COC=C1': 21,
#              'C1=COC=CC1': 15,
#              'C1=COC=CCC1': 2,
#              'C1=COC=CN=CN=C1': 1,
#              'C1=COC=N1': 15,
#              'C1=COC=NC1': 19,
#              'C1=COC=NC=CN=C1': 1,
#              'C1=COC=NC=NC=N1': 1,
#              'C1=COC=NCC1': 4,
#              'C1=COCC1': 11,
#              'C1=COCC=N1': 18,
#              'C1=COCC=NC1': 4,
#              'C1=COCCC1': 2,
#              'C1=COCCC=N1': 4,
#              'C1=COCCN1': 11,
#              'C1=COCCN=C1': 4,
#              'C1=COCCO1': 5,
#              'C1=COCN1': 25,
#              'C1=COCN=C1': 16,
#              'C1=COCN=CC1': 4,
#              'C1=COCNC1': 10,
#              'C1=COCO1': 7,
#              'C1=COCOC1': 9,
#              'C1=COC[N-]1': 5,
#              'C1=CON=C1': 19,
#              'C1=CON=CC1': 19,
#              'C1=CON=CCC1': 4,
#              'C1=CON=N1': 7,
#              'C1=CON=NC1': 11,
#              'C1=CON=NCC1': 4,
#              'C1=CSC=C1': 22,
#              'C1=CSC=N1': 10,
#              'C1=CSCC1': 11,
#              'C1=C[CH-]C=C1': 2,
#              'C1=C[N-]C=N1': 2,
#              'C1=C[N-]C=[NH+]C1': 3,
#              'C1=C[N-]CN=C1': 7,
#              'C1=C[N-]C[NH+]=C1': 2,
#              'C1=C[N-]N=C1': 3,
#              'C1=C[N-]N=CC1': 9,
#              'C1=C[N-]N=N1': 5,
#              'C1=C[N-]N=NC1': 4,
#              'C1=C[NH+]=CC1': 2,
#              'C1=C[NH+]=CCN1': 2,
#              'C1=C[NH+]=CNC1': 4,
#              'C1=C[NH+]=COC1': 2,
#              'C1=C[NH+]=C[NH]1': 7,
#              'C1=C[NH2+]CC1': 2,
#              'C1=C[NH2+][CH-]C1': 7,
#              'C1=C[NH]C=C1': 47,
#              'C1=C[NH]C=CN=CN=C1': 1,
#              'C1=C[NH]C=N1': 39,
#              'C1=C[NH]C=NC=CN=C1': 1,
#              'C1=C[NH]C=NC=NC=N1': 1,
#              'C1=C[NH]N=C1': 38,
#              'C1=C[NH]N=N1': 15,
#              'C1=C[Se]C=C1': 1,
#              'C1=C[SiH2]C=C1': 6,
#              'C1=NC=COC=CN=C1': 1,
#              'C1=NC=C[NH]C=CN=C1': 1,
#              'C1=NC=NC1': 3,
#              'C1=NC=NC=N1': 4,
#              'C1=NC=NC=NC1': 7,
#              'C1=NC=NCC1': 3,
#              'C1=NC=NCCN1': 4,
#              'C1=NC=NCCO1': 4,
#              'C1=NC=NCN1': 16,
#              'C1=NC=NCN=C1': 7,
#              'C1=NC=NCNC1': 4,
#              'C1=NC=NCO1': 9,
#              'C1=NC=NCOC1': 4,
#              'C1=NC=NN=C1': 4,
#              'C1=NC=NN=N1': 1,
#              'C1=NC=NNC1': 15,
#              'C1=NC=NNCC1': 4,
#              'C1=NC=NOC1': 11,
#              'C1=NC=NOCC1': 4,
#              'C1=NC=[NH+][N-]C1': 4,
#              'C1=NCC=NCN1': 4,
#              'C1=NCC=NCO1': 4,
#              'C1=NCC=NN1': 15,
#              'C1=NCC=NNC1': 4,
#              'C1=NCC=NO1': 11,
#              'C1=NCC=NOC1': 4,
#              'C1=NCC=N[N-]1': 4,
#              'C1=NCCC1': 32,
#              'C1=NCCC=NN1': 2,
#              'C1=NCCC=NO1': 4,
#              'C1=NCCCC1': 25,
#              'C1=NCCCCC1': 6,
#              'C1=NCCCCCCO1': 1,
#              'C1=NCCCCCO1': 15,
#              'C1=NCCCCN1': 8,
#              'C1=NCCCCO1': 51,
#              'C1=NCCCCOCO1': 1,
#              'C1=NCCCN1': 55,
#              'C1=NCCCN=CN1': 1,
#              'C1=NCCCNC1': 4,
#              'C1=NCCCNCO1': 1,
#              'C1=NCCCO1': 45,
#              'C1=NCCCOC1': 5,
#              'C1=NCCCOCCO1': 1,
#              'C1=NCCCOCN1': 1,
#              'C1=NCCCOCO1': 8,
#              'C1=NCCN1': 46,
#              'C1=NCCN=C1': 7,
#              'C1=NCCN=CN1': 7,
#              'C1=NCCN=CO1': 2,
#              'C1=NCCN=COCO1': 1,
#              'C1=NCCN=NN1': 2,
#              'C1=NCCN=NO1': 4,
#              'C1=NCCNC1': 19,
#              'C1=NCCNCC1': 4,
#              'C1=NCCNCCO1': 11,
#              'C1=NCCNCN1': 12,
#              'C1=NCCNCO1': 11,
#              'C1=NCCNN=C1': 4,
#              'C1=NCCNN=N1': 4,
#              'C1=NCCO1': 19,
#              'C1=NCCOC1': 21,
#              'C1=NCCOCC1': 6,
#              'C1=NCCOCCCO1': 1,
#              'C1=NCCOCCN1': 1,
#              'C1=NCCOCCO1': 8,
#              'C1=NCCOCN1': 10,
#              'C1=NCCOCO1': 22,
#              'C1=NCCON=C1': 4,
#              'C1=NCCON=N1': 4,
#              'C1=NCCS1': 5,
#              'C1=NCN=CN1': 10,
#              'C1=NCN=CN=N1': 1,
#              'C1=NCN=CNC1': 4,
#              'C1=NCN=CO1': 5,
#              'C1=NCN=COC1': 4,
#              'C1=NCN=C[N-]1': 2,
#              'C1=NCN=NN1': 9,
#              'C1=NCN=NNC1': 4,
#              'C1=NCN=NO1': 4,
#              'C1=NCN=NOC1': 4,
#              'C1=NCN=N[N-]1': 2,
#              'C1=NCNC1': 2,
#              'C1=NCNCN1': 10,
#              'C1=NCNCN=C1': 2,
#              'C1=NCNCO1': 8,
#              'C1=NCNN=C1': 15,
#              'C1=NCNN=CC1': 4,
#              'C1=NCNN=N1': 9,
#              'C1=NCNN=NC1': 4,
#              'C1=NCOCN1': 8,
#              'C1=NCOCN=C1': 2,
#              'C1=NCOCO1': 6,
#              'C1=NCON=C1': 9,
#              'C1=NCON=CC1': 4,
#              'C1=NCON=N1': 4,
#              'C1=NCON=NC1': 4,
#              'C1=NC[N-]CO1': 2,
#              'C1=NC[N-]N=C1': 4,
#              'C1=NC[NH+]=C[N-]1': 7,
#              'C1=NN=CCC1': 4,
#              'C1=NN=CCNC1': 2,
#              'C1=NN=CN=N1': 2,
#              'C1=NN=CO1': 3,
#              'C1=NN=C[NH]1': 6,
#              'C1=NN=NC=N1': 1,
#              'C1=NN=NN=C1': 1,
#              'C1=NN=NO1': 1,
#              'C1=NN=N[NH]1': 3,
#              'C1=NNCCN1': 10,
#              'C1=NNCCO1': 4,
#              'C1=NNCN1': 22,
#              'C1=NNCNC1': 10,
#              'C1=NNCO1': 13,
#              'C1=NNCOC1': 8,
#              'C1=NNC[N-]1': 2,
#              'C1=NNN=CC1': 9,
#              'C1=NNN=CCC1': 2,
#              'C1=NNN=NC1': 8,
#              'C1=NNN=NCC1': 2,
#              'C1=NOC=N1': 5,
#              'C1=NOCCN1': 8,
#              'C1=NOCCO1': 6,
#              'C1=NOCN1': 14,
#              'C1=NOCNC1': 8,
#              'C1=NOCO1': 4,
#              'C1=NOCOC1': 6,
#              'C1=NOC[N-]1': 4,
#              'C1=NON=C1': 5,
#              'C1=NON=CC1': 7,
#              'C1=NON=CCC1': 2,
#              'C1=NON=N1': 2,
#              'C1=NON=NC1': 6,
#              'C1=NON=NCC1': 4,
#              'C1=NSN=C1': 2,
#              'C1=N[CH-]CO1': 4,
#              'C1=N[N-]C=N1': 4,
#              'C1=N[N-]C=[NH+]C1': 7,
#              'C1=N[N-]CO1': 4,
#              'C1=N[N-]N=CC1': 2,
#              'C1=N[N-]N=N1': 1,
#              'C1=N[N-]N=NC1': 2,
#              'C1=N[NH]C=N1': 14,
#              'C1=N[NH]N=C1': 9,
#              'C1=N[NH]N=N1': 4,
#              'C1=S=CCC1': 2,
#              'C1=[NH+]CCC1': 4,
#              'C1=[NH+]CCCN1': 3,
#              'C1=[NH+]CCN1': 14,
#              'C1=[NH+]CCO1': 2,
#              'C1=[NH+]CC[CH-]1': 2,
#              'C1=[NH+]C[CH-]C1': 2,
#              'C1=[NH+][CH-]CC1': 2,
#              'C1=[NH+][CH-]CCN1': 2,
#              'C1C2C1N1CC21': 5,
#              'C1C2CC1C2': 6,
#              'C1C2CC1N2': 11,
#              'C1C2CC1O2': 6,
#              'C1C2CN1C2': 5,
#              'C1C2CN3C1C23': 5,
#              'C1C2OC3C1C23': 5,
#              'C1CC1': 5,
#              'C1CC2CC12': 13,
#              'C1CC2CC2O1': 6,
#              'C1CC2NC12': 13,
#              'C1CC2OC12': 8,
#              'C1CC2OCC12': 5,
#              'C1CCC1': 11,
#              'C1CCCC1': 19,
#              'C1CCCCC1': 31,
#              'C1CCCCCC1': 19,
#              'C1CCCCCCC1': 4,
#              'C1CCCCCCCC1': 1,
#              'C1CCCCOCCC1': 1,
#              'C1CCCNCC1': 34,
#              'C1CCCNCCC1': 1,
#              'C1CCCOCC1': 58,
#              'C1CCCOCCC1': 13,
#              'C1CCCOCOCC1': 1,
#              'C1CCNC1': 73,
#              'C1CCNCC1': 124,
#              'C1CCNCNC1': 12,
#              'C1CCNCNCC1': 1,
#              'C1CCNCOCC1': 1,
#              'C1CCOC1': 39,
#              'C1CCOCC1': 75,
#              'C1CCOCCCOC1': 1,
#              'C1CCOCCNC1': 7,
#              'C1CCOCCOC1': 9,
#              'C1CCOCCOCC1': 1,
#              'C1CCOCNC1': 17,
#              'C1CCOCOC1': 32,
#              'C1CCOCOCC1': 9,
#              'C1CC[N-]C1': 3,
#              'C1CC[NH2+]C1': 22,
#              'C1CC[NH2+]CC1': 3,
#              'C1CC[SiH2]C1': 5,
#              'C1CN1': 11,
#              'C1CN2CC12': 16,
#              'C1CN=NNN=N1': 2,
#              'C1CN=NON=N1': 2,
#              'C1CNC1': 33,
#              'C1CNCCCOC1': 2,
#              'C1CNCCN1': 49,
#              'C1CNCCNC1': 20,
#              'C1CNCCOC1': 64,
#              'C1CNCN1': 35,
#              'C1CNCNC1': 39,
#              'C1CNCNCN1': 2,
#              'C1CNCOC1': 46,
#              'C1CNCOCOC1': 1,
#              'C1CNC[N-]1': 2,
#              'C1CNN=N1': 5,
#              'C1CNN=NN1': 4,
#              'C1CO1': 6,
#              'C1COC1': 17,
#              'C1COCCCOC1': 5,
#              'C1COCCN1': 71,
#              'C1COCCNCN1': 1,
#              'C1COCCO1': 21,
#              'C1COCCOC1': 34,
#              'C1COCCOCCO1': 1,
#              'C1COCCOCN1': 1,
#              'C1COCCOCOC1': 1,
#              'C1COCC[NH2+]1': 2,
#              'C1COCN1': 28,
#              'C1COCNCN1': 4,
#              'C1COCNCO1': 2,
#              'C1COCO1': 20,
#              'C1COCOC1': 36,
#              'C1COCOCCN1': 5,
#              'C1COCOCCO1': 5,
#              'C1COCOCN1': 13,
#              'C1COCOCO1': 7,
#              'C1COCOCOC1': 1,
#              'C1COC[N-]1': 2,
#              'C1CON=N1': 3,
#              'C1CON=NN1': 4,
#              'C1CON=NO1': 2,
#              'C1CSCCN1': 2,
#              'C1CSCN1': 2,
#              'C1CSCS1': 2,
#              'C1C[N-]C1': 6,
#              'C1C[NH2+]1': 6,
#              'C1C[NH2+]C1': 24,
#              'C1C[NH2+]CCN1': 1,
#              'C1N=NNCN1': 8,
#              'C1N=NNCO1': 6,
#              'C1N=NNN=N1': 4,
#              'C1N=NOCN1': 6,
#              'C1N=NOCO1': 4,
#              'C1N=NON=N1': 1,
#              'C1NC2CC12': 25,
#              'C1NCNCN1': 2,
#              'C1NCOCN1': 2,
#              'C1NCOCO1': 6,
#              'C1NN=NN1': 7,
#              'C1NN=NO1': 7,
#              'C1OC2CC12': 16,
#              'C1ON=NO1': 1,
#              'C1[N-]N=NO1': 1,
#              'C=C': 2,
#              'C=N': 4,
#              'C=NC': 4,
#              'C=NCC': 4,
#              'C=NO': 3,
#              'C=O': 3,
#              'C=S': 1,
#              'C=[NH2+]': 4,
#              'CBr': 3,
#              'CC': 2,
#              'CC#CC': 2,
#              'CC#CC#N': 3,
#              'CC#CC=O': 3,
#              'CC#CCC': 6,
#              'CC#CCO': 3,
#              'CC#N': 3,
#              'CC(=N)N': 4,
#              'CC(=O)C#N': 3,
#              'CC(=O)C=O': 3,
#              'CC(=O)CO': 3,
#              'CC(=O)[O-]': 3,
#              'CC(C)(C)C': 3,
#              'CC(C)(C)O': 5,
#              'CC(C)=NO': 4,
#              'CC(C)=O': 4,
#              'CC(C)C': 3,
#              'CC(C)C#N': 4,
#              'CC(C)C=O': 4,
#              'CC(C)CO': 4,
#              'CC(C)N': 5,
#              'CC(C)O': 4,
#              'CC(F)(F)F': 3,
#              'CC(N)=O': 6,
#              'CC(N)C#N': 6,
#              'CC(O)C#N': 3,
#              'CC(O)C=O': 3,
#              'CC(O)CO': 3,
#              'CC1(C)CC1': 5,
#              'CC1(C)CN1': 8,
#              'CC1(O)CC1': 5,
#              'CC1=CSC=C1': 8,
#              'CC1C=CCC1': 11,
#              'CC1CC1': 10,
#              'CC1CC1C': 10,
#              'CC1CC1O': 16,
#              'CC1CC2CC12': 11,
#              'CC1CCC1': 18,
#              'CC1CCN1': 27,
#              'CC1CCO1': 16,
#              'CC1CCOC1': 9,
#              'CC1CN1': 16,
#              'CC1CN1C': 9,
#              'CC1CO1': 8,
#              'CC1COC1': 10,
#              'CC1NC1C': 10,
#              'CC=O': 3,
#              'CCC': 4,
#              'CCC#N': 3,
#              'CCC(C)=O': 6,
#              'CCC(C)C': 6,
#              'CCC(C)O': 6,
#              'CCC(N)=O': 6,
#              'CCC=O': 3,
#              'CCCC': 4,
#              'CCCC#N': 3,
#              'CCCC=O': 3,
#              'CCCCC': 4,
#              'CCCCCCC': 2,
#              'CCCCO': 3,
#              'CCCN': 6,
#              'CCCO': 3,
#              'CCCOC': 6,
#              'CCN': 6,
#              'CCNC': 4,
#              'CCNC=O': 3,
#              'CCO': 3,
#              'CCOC': 6,
#              'CCOC=N': 3,
#              'CCOC=O': 3,
#              'CCOCC': 4,
#              'CC[NH3+]': 4,
#              'CCl': 3,
#              'CF': 3,
#              'CN': 4,
#              'CN(C)C': 3,
#              'CN1CC1': 5,
#              'CN1CCC1': 10,
#              'CN=COC': 4,
#              'CNC': 2,
#              'CNC(C)=O': 6,
#              'CNC(N)=O': 6,
#              'CNC=N': 3,
#              'CNC=O': 3,
#              'CO': 4,
#              'COC': 2,
#              'COC(C)=O': 7,
#              'COC(C)C': 6,
#              'COC(N)=O': 6,
#              'COC=N': 3,
#              'COC=O': 3,
#              'CS': 4,
#              'C[N+](=O)[O-]': 3,
#              'C[NH-]': 4,
#              'C[NH3+]': 4,
#              'C[O-]': 3,
#              'C[SiH3]': 4,
#              'N': 1,
#              'N#CCN': 3,
#              'N1=NON=N1': 1,
#              'N1=N[NH]N=N1': 1,
#              'N=C1CCO1': 8,
#              'N=CN': 3,
#              'NC(N)=O': 4,
#              'NC=O': 3,
#              'NCC=O': 3,
#              'NCCO': 3,
#              'NO': 3,
#              'N[O-]': 3,
#              'O=C1CCC1': 10,
#              'O=C1CCN1': 14,
#              'O=C1CCO1': 8,
#              'O=C1CNC1': 9,
#              'O=S': 1,
#              'OC12CCC1C2': 9,
#              'OC1C=CCC1': 11,
#              'OC1CC1': 10,
#              'OC1CC1O': 10,
#              'OC1CC2CC12': 11,
#              'OC1CCC1': 18,
#              'OC1CNC1': 18,
#              'OC1COC1': 10,
#              'S': 1,
#              '[CH-]1CC1': 4,
#              '[CH-]1CCC1': 9,
#              '[CH-]1CCCC1': 2,
#              '[CH-]1CCCCC1': 2,
#              '[CH-]1CCC[NH2+]1': 7,
#              '[CH-]1CCNC1': 2,
#              '[CH-]1CCNCN1': 2,
#              '[CH-]1CC[NH2+]1': 7,
#              '[CH-]1CC[NH2+]C1': 10,
#              '[CH-]1CC[NH2+]CC1': 4,
#              '[CH-]1COC1': 2,
#              '[CH-]1C[NH2+]C1': 2,
#              '[CH2-]C': 4,
#              '[CH2-]N': 2,
#              '[CH2-]O': 4,
#              '[CH2-][NH3+]': 2,
#              '[CH3-]': 1,
#              '[NH4+]': 1,
#              '[SiH4]': 1})

# %%
max(x)
# Out:
# 124

# %%
[motif for motif in motif_list if 'C1CCNCC1' in motif]
# Out:
# ['C1CCNCC1 C1CC[CH2:1]NC1 False\n',
#  'C1CCNCC1 C1CC[CH2:2][NH:1]C1 False\n',
#  'C1CCNCC1 C1CC[NH:1]CC1 False\n',
#  'C1CCNCC1 C1CC[NH:1][CH2:1]C1 False\n',
#  'C1CCNCC1 C1CC[NH:2][CH2:1]C1 False\n',
#  'C1CCNCC1 C1CNC[CH2:1]C1 False\n',
#  'C1CCNCC1 C1CN[CH2:1][CH2:1]C1 False\n',
#  'C1CCNCC1 C1CN[CH2:1][CH2:2]C1 False\n',
#  'C1CCNCC1 C1CN[CH2:2][CH2:1]C1 False\n',
#  'C1CCNCC1 C1C[CH2:1]CCN1 False\n',
#  'C1CCNCC1 C1C[CH2:1]C[CH2:2]N1 False\n',
#  'C1CCNCC1 C1C[CH2:1]C[NH:2]C1 False\n',
#  'C1CCNCC1 C1C[CH2:1]N[CH2:2]C1 False\n',
#  'C1CCNCC1 C1C[CH2:1][CH2:1][CH2:1]N1 False\n',
#  'C1CCNCC1 C1C[CH2:1][CH2:1][CH2:2]N1 False\n',
#  'C1CCNCC1 C1C[CH2:1][CH2:1][NH:1]C1 False\n',
#  'C1CCNCC1 C1C[CH2:1][CH2:2]CN1 False\n',
#  'C1CCNCC1 C1C[CH2:1][CH2:2][CH2:2]N1 False\n',
#  'C1CCNCC1 C1C[CH2:1][CH2:2][NH:2]C1 False\n',
#  'C1CCNCC1 C1C[CH2:1][NH:1][CH2:2]C1 False\n',
#  'C1CCNCC1 C1C[CH2:1][NH:2][CH2:2]C1 False\n',
#  'C1CCNCC1 C1C[CH2:2]CC[NH:1]1 False\n',
#  'C1CCNCC1 C1C[CH2:2]CN[CH2:1]1 False\n',
#  'C1CCNCC1 C1C[CH2:2]C[CH2:1]N1 False\n',
#  'C1CCNCC1 C1C[CH2:2]C[CH2:1][NH:1]1 False\n',
#  'C1CCNCC1 C1C[CH2:2]C[CH2:2][NH:1]1 False\n',
#  'C1CCNCC1 C1C[CH2:2]C[NH:1][CH2:1]1 False\n',
#  'C1CCNCC1 C1C[CH2:2]C[NH:2][CH2:1]1 False\n',
#  'C1CCNCC1 C1C[CH2:2]NC[CH2:1]1 False\n',
#  'C1CCNCC1 C1C[CH2:2]N[CH2:1][CH2:1]1 False\n',
#  'C1CCNCC1 C1C[CH2:2]N[CH2:2][CH2:1]1 False\n',
#  'C1CCNCC1 C1C[CH2:2][CH2:1]CN1 False\n',
#  'C1CCNCC1 C1C[CH2:2][CH2:1]N[CH2:2]1 False\n',
#  'C1CCNCC1 C1C[CH2:2][CH2:1][CH2:1]N1 False\n',
#  'C1CCNCC1 C1C[CH2:2][CH2:1][CH2:2]N1 False\n',
#  'C1CCNCC1 C1C[CH2:2][CH2:1][NH:2]C1 False\n',
#  'C1CCNCC1 C1C[CH2:2][CH2:2]C[NH:1]1 False\n',
#  'C1CCNCC1 C1C[CH2:2][CH2:2]N[CH2:1]1 False\n',
#  'C1CCNCC1 C1C[CH2:2][CH2:2][CH2:1]N1 False\n',
#  'C1CCNCC1 C1C[CH2:2][CH2:2][CH2:1][NH:1]1 False\n',
#  'C1CCNCC1 C1C[CH2:2][CH2:2][CH2:2][NH:1]1 False\n',
#  'C1CCNCC1 C1C[CH2:2][CH2:2][NH:1][CH2:1]1 False\n',
#  'C1CCNCC1 C1C[CH2:2][CH2:2][NH:1][CH2:2]1 False\n',
#  'C1CCNCC1 C1C[CH2:2][CH2:2][NH:2][CH2:1]1 False\n',
#  'C1CCNCC1 C1C[CH2:2][NH:1]C[CH2:2]1 False\n',
#  'C1CCNCC1 C1C[CH2:2][NH:1][CH2:2]C1 False\n',
#  'C1CCNCC1 C1C[CH2:2][NH:2]C[CH2:1]1 False\n',
#  'C1CCNCC1 C1C[CH2:2][NH:2][CH2:1][CH2:1]1 False\n',
#  'C1CCNCC1 C1C[CH2:2][NH:2][CH2:1][CH2:2]1 False\n',
#  'C1CCNCC1 C1C[CH2:2][NH:2][CH2:2][CH2:1]1 False\n',
#  'C1CCNCC1 C1C[NH:1]C[CH2:2]C1 False\n',
#  'C1CCNCC1 C1C[NH:1][CH2:1][CH2:2]C1 False\n',
#  'C1CCNCC1 C1C[NH:1][CH2:2][CH2:2]C1 False\n',
#  'C1CCNCC1 C1C[NH:2]CC[CH2:1]1 False\n',
#  'C1CCNCC1 C1C[NH:2]C[CH2:1][CH2:2]1 False\n',
#  'C1CCNCC1 C1C[NH:2]C[CH2:2][CH2:1]1 False\n',
#  'C1CCNCC1 C1C[NH:2][CH2:1]C[CH2:2]1 False\n',
#  'C1CCNCC1 C1C[NH:2][CH2:1][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1C[NH:2][CH2:2]C[CH2:1]1 False\n',
#  'C1CCNCC1 C1C[NH:2][CH2:2][CH2:1][CH2:1]1 False\n',
#  'C1CCNCC1 C1C[NH:2][CH2:2][CH2:1][CH2:2]1 False\n',
#  'C1CCNCC1 C1C[NH:2][CH2:2][CH2:2][CH2:1]1 False\n',
#  'C1CCNCC1 C1NC[CH2:2]C[CH2:1]1 False\n',
#  'C1CCNCC1 C1NC[CH2:2][CH2:1][CH2:1]1 False\n',
#  'C1CCNCC1 C1NC[CH2:2][CH2:1][CH2:2]1 False\n',
#  'C1CCNCC1 C1NC[CH2:2][CH2:2][CH2:1]1 False\n',
#  'C1CCNCC1 C1N[CH2:1]C[CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1N[CH2:1][CH2:1]C[CH2:2]1 False\n',
#  'C1CCNCC1 C1N[CH2:1][CH2:1][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1N[CH2:1][CH2:2]C[CH2:2]1 False\n',
#  'C1CCNCC1 C1N[CH2:1][CH2:2][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1N[CH2:2]C[CH2:1][CH2:1]1 False\n',
#  'C1CCNCC1 C1N[CH2:2]C[CH2:2][CH2:1]1 False\n',
#  'C1CCNCC1 C1N[CH2:2][CH2:1]C[CH2:2]1 False\n',
#  'C1CCNCC1 C1N[CH2:2][CH2:1][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1N[CH2:2][CH2:2]C[CH2:1]1 False\n',
#  'C1CCNCC1 C1N[CH2:2][CH2:2][CH2:1][CH2:2]1 False\n',
#  'C1CCNCC1 C1N[CH2:2][CH2:2][CH2:2][CH2:1]1 False\n',
#  'C1CCNCC1 C1[CH2:1]C[CH2:2]N[CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1]C[CH2:2][NH:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1]C[NH:2]C[CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1]C[NH:2][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1]N[CH2:2]C[CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1]N[CH2:2][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1][CH2:1]C[NH:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1][CH2:2]CN[CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1][CH2:2]C[NH:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1][CH2:2]N[CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1][CH2:2][CH2:2]N[CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1][CH2:2][CH2:2][CH2:2][NH:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1][CH2:2][CH2:2][NH:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1][CH2:2][NH:2]C[CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1][CH2:2][NH:2][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1][NH:1]C[CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1][NH:1][CH2:2][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1][NH:2]C[CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1][NH:2][CH2:2]C[CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:1][NH:2][CH2:2][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:2]N[CH2:1][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:2][CH2:1]C[NH:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:2][CH2:1]N[CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:2][CH2:2][CH2:1][CH2:2][NH:2]1 False\n',
#  'C1CCNCC1 C1[CH2:2][CH2:2][CH2:1][NH:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[CH2:2][NH:1][CH2:2][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[NH:1]C[CH2:2]C[CH2:2]1 False\n',
#  'C1CCNCC1 C1[NH:1]C[CH2:2][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[NH:1][CH2:1][CH2:2][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[NH:1][CH2:2]C[CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 C1[NH:1][CH2:2][CH2:2]C[CH2:2]1 False\n',
#  'C1CCNCC1 N1[CH2:1][CH2:2][CH2:2][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 [CH2:1]1[CH2:1][CH2:1][NH:2][CH2:2][CH2:1]1 False\n',
#  'C1CCNCC1 [CH2:1]1[CH2:1][CH2:2][CH2:2][CH2:1][NH:1]1 False\n',
#  'C1CCNCC1 [CH2:1]1[CH2:1][CH2:2][CH2:2][CH2:2][NH:1]1 False\n',
#  'C1CCNCC1 [CH2:1]1[CH2:1][CH2:2][CH2:2][NH:2][CH2:1]1 False\n',
#  'C1CCNCC1 [CH2:1]1[CH2:1][CH2:2][NH:2][CH2:2][CH2:1]1 False\n',
#  'C1CCNCC1 [CH2:1]1[CH2:1][CH2:2][NH:2][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 [CH2:1]1[CH2:1][NH:1][CH2:2][CH2:2][CH2:1]1 False\n',
#  'C1CCNCC1 [CH2:1]1[CH2:1][NH:2][CH2:2][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 [CH2:1]1[CH2:2][CH2:2][CH2:2][CH2:2][NH:2]1 False\n',
#  'C1CCNCC1 [CH2:1]1[CH2:2][CH2:2][CH2:2][NH:2][CH2:2]1 False\n',
#  'C1CCNCC1 [CH2:1]1[CH2:2][CH2:2][NH:2][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 [CH2:1]1[NH:1][CH2:1][CH2:2][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 [CH2:1]1[NH:1][CH2:2][CH2:2][CH2:2][CH2:2]1 False\n',
#  'C1CCNCC1 [NH:1]1[CH2:2][CH2:2][CH2:2][CH2:2][CH2:2]1 False\n']
